# %%
import pandas as pd
import numpy as np
import seaborn as sns
#import dask.dataframe as dd
#from distributed import Client
#from dask import delayed
import os
import pymongo
import geopandas as gpds
from haversine import haversine
from geopy.geocoders import Nominatim
from pymongo import MongoClient
from pipeline import *

import mongo_proxy

# %%
ultimas_linhas
# Out:
# [499999,
#  499999,
#  499999,
#  499999,
#  499999,
#  499999,
#  499999,
#  499999,
#  499999,
#  499999,
#  499999,
#  499999,
#  417511]

# %%
df_slice[df_slice['Distancia do ponto']<5]['Logradouro']
# Out:
# 2026     BRIG LUIS ANTONIO
# 2027     BRIG LUIS ANTONIO
# 2028     BRIG LUIS ANTONIO
# 2029     BRIG LUIS ANTONIO
# 2030     BRIG LUIS ANTONIO
#                ...
# 36245           LEON BERRY
# 36362              MARACAI
# 36364    NEVES DE CARVALHO
# 36448        PAULISTA 2202
# 36456           PERNAMBUCO
# Name: Logradouro, Length: 2051, dtype: object

# %%
os.chdir('/home/andrius/Downloads')
dtype={'CNPJ Bas': object, 'CNPJ Ord': object,
'CNPJ DV': object,'Identificador': 'category','Nome Fantasia': object,
'Situaçao Cadastral': 'category','Data Sit.Cad.': object,'Motivo Sit.Cad.': object,'Nome Cidade Ext': object,'Pais': object,'Data de Inicio': object,
'CNAE Principal': object,'CNAESeg': object,'Tipo de Logradouro': object,'Logradouro': object,'Numero':object,'Complemento': object,'Bairro': object,
'CEP': object,'UF': object,'Municipio': object,'DDD1': object,'Tel1': object,'DDD2': object,'Tel2': object,'DDD Fax': object,'FAX': object,'email': object,'Situação': object,'Data da Situação':  object}
colunas=['CNPJ Bas','CNPJ Ord','CNPJ DV','Identificador','Nome Fantasia',
'Situaçao Cadastral','Data Sit.Cad.','Motivo Sit.Cad.','Nome Cidade Ext','Pais','Data de Inicio',
'CNAE Principal','CNAESeg','Tipo de Logradouro','Logradouro','Numero','Complemento','Bairro',
'CEP','UF','Municipio','DDD1','Tel1','DDD2','Tel2','DDD Fax','FAX','email','Situação','Data da Situação']

client=MongoClient('localhost', 27017,connectTimeoutMS=0)
db_string='Resultado2'
db=client[db_string]




count=0

cidade=pd.read_csv('Codigo Cidades.csv',delimiter=';',encoding='latin',names=['Codigo','Cidade'],dtype=object)

ultimas_linhas=[]

for chunk in pd.read_csv('case.csv',delimiter=';',encoding='latin',names=colunas,dtype=dtype,chunksize=500000):
          
    df_slice,df_dict,out_dist=pre_process(chunk,cidade)
    ultimas_linhas.append(df_slice.index[-1])
    collection=db['Estabelecimentos']
    ##remover dps
    print(df_slice['Situaçao Cadastral'].value_counts()['02'])
    print(df_slice[df_slice['CNAE Principal'].str.startswith('561')]['Ano de Inicio'].value_counts())
    print('<5='+str(df_slice[df_slice['Distancia do ponto']<5].shape[0]))
    
    
    ##
    
    collection.insert_many(df_dict)
   
    db_queries(collection,db,db_string,count)
    
    collection.remove({})
    count=count+1
    

queries_final(db,db_string)
export(coll_finais=db['Finais'],coll_cnae=db['FinalCnae'])
# Out:
# /home/andrius/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/andrius/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# End unicos=937
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('SP, SAO PAULO, SE, PRACA SE',), **{}).
# Traceback (most recent call last):
# ...

# %%
df_slice=pd.read_csv('case.csv',delimiter=';',encoding='latin',names=colunas,dtype=dtype,nrows=250000)

# %%
 df_slice.loc[:,'Endereco']=df_slice[
    ['UF','Bairro']].astype(str).agg(', '.join, axis=1)

# %%
 df_slice.loc[:,'Endereco']
# Out:
# 0                         MG, centro
# 1                  GO, CIDADE JARDIM
# 2                    SE, SAO CONRADO
# 3                MA, VILA SAO JOSE I
# 4             SP, QUINTA DA PAINEIRA
#                      ...
# 249995        RN, CAMINHO DAS SERRAS
# 249996    SP, JARDIM PALMA TRAVASSOS
# 249997                    MG, GUINDA
# 249998      AL, TABULEIRO DO MARTINS
# 249999              SP, VILA INGLESA
# Name: Endereco, Length: 250000, dtype: object

# %%
#df=pd.read_csv('case.csv',delimiter=';',encoding='latin',names=colunas,dtype=dtype,nrows=2500)
from geopy.geocoders import Nominatim


from geopy.extra.rate_limiter import RateLimiter
#unique_adrs=(df[df['CEP'].str[:5].apply(lambda x: True if str(x)<'01599' 
#                                            and str(x)>'01000' else False)]).drop_duplicates('Logradouro')
unique_adrs=out_dist
geolocator = Nominatim(user_agent="carlos")                                            
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
#unique_adrs['location']=unique_adrs['Endereco'].apply(geocode)
#unique_adrs['point']=unique_adrs['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ceb27bdd80ca> in <module>
#       9 geolocator = Nominatim(user_agent="carlos")
#      10 geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
# ---> 11 unique_adrs['location']=unique_adrs['Endereco'].apply(geocode)
#      12 unique_adrs['point']=unique_adrs['location'].apply(lambda loc: tuple(loc.point) if loc else None)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
def distance(row):
    ###################
    #Função para calcular a distancia de haversine (distancia superfície esférica com base e lat/long) 
    # entre ponto de referencia CEP=01422000
    ##################
        
    print(row[0])
    print(row[1])
    if row !=None:
        return haversine((row[0],row[1]),
                          (-23.567402486525495, -46.6569533755973),unit='km')
    else:
        return np.NaN
distance(geocode(out_dist['Endereco'].iloc[0]).point)
# Out:
# -23.5299633
# -46.6341997
# 4.765563485338909

# %%
unique_adrs['Endereco'].iloc[0]
# Out:
# 'SP, SAO PAULO, RUA TRES RIOS'

# %%
geocode(unique_adrs['Endereco'].iloc[0]).point[1]
# Out:
# -45.8038315

# %%
23.1852267
# Out:
# 23.1852267

# %%
haversine((-23.18, -45.80),
                          (-23.56, -46.65))
# Out:
# 96.50381596640868

# %%
unique_adrs['point'].apply(distance)
# Out:
# 29     3249.017182
# 42     3275.626888
# 43     3290.948478
# 55     3292.157006
# 78     3274.792453
# 99     3289.431305
# 105    3290.674850
# 129    3294.301235
# 131    3324.613350
# 162    3293.368522
# 179    3292.830712
# 182    3407.027635
# 194    3280.246052
# 195    3291.795770
# 209    3288.193343
# 222    3252.371144
# 237    3291.227288
# 245    3290.821116
# 282    3615.950776
# 286    3292.601498
# 334    3292.378177
# 340    3289.234969
# 366    3292.247956
# 386    3296.128005
# 397    3291.856132
# 414    3292.515836
# 425    3397.330725
# 432    3291.336244
# 442    3288.691784
# 449    3242.670469
# 458    3291.538136
# 464    3291.600628
# 485    3288.472616
# 491    3290.628327
# 497    3290.480042
# 499    3291.361015
# 504    3311.046511
# 513    3254.882784
# 514    3437.262968
# 539    3287.622315
# 544    3293.315346
# 550    3387.726158
# 556    3362.034274
# 560    3291.239967
# 567    3292.921730
# 571    3277.086770
# 583    3271.889039
# ...

# %%
endereço1=geocode(['Santo André Rua Ituverava 135'])
endereço2=geocode(['Santo André Avenida Portugal '])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-72317dc83f10> in <module>
# ----> 1 endereço1=geocode(['Santo André Rua Ituverava 135'])
#       2 endereço2=geocode(['Santo André Avenida Portugal '])
#
# NameError: name 'geocode' is not defined

# %%
haversine((endereço1.point[1],endereço1.point[0]),(endereço2.point[1],endereço2.point[0]))<5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-442a96df9230> in <module>
# ----> 1 haversine((endereço1.point[1],endereço1.point[0]),(endereço2.point[1],endereço2.point[0]))<5
#
# NameError: name 'endereço1' is not defined

# %%
haversine((-23.1852267, -45.8038315),
                          (-23.567402486525495, -46.6569533755973))
# Out:
# 96.89253680503329
